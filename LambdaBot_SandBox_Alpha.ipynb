# %%
# !pip install telepot
# !pip install wget
# !pip install pprint
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 81kB 5.8MB/s
# ...
#      |████████████████████████████████| 1.2MB 25.8MB/s
# ...
#      |████████████████████████████████| 256kB 50.1MB/s
# ...
#      |████████████████████████████████| 153kB 49.3MB/s
# ...
#   Created wheel for telepot: filename=telepot-12.7-cp36-none-any.whl size=57964 sha256=84a9cb19c61fac3c8c098b0545372e13ec8b04bafd57e70aad8899c3cdd47ad4
#   Stored in directory: /root/.cache/pip/wheels/65/17/50/983034e27e6b5d8dfc497a51b5b13d970d8018a83f47e6513a
# ...
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3163 sha256=c69bca0bcfa42ae1a12eeb6cdffe04fef6e90b113f4eef8cc0ec86bdff0f196d
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
# Successfully built telepot idna-ssl
# ...
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9681 sha256=f0d3828bdb1e1666ea9043dc3219306a06706e77814a281c1857567987759918
# ...

# %%
import sys
import time
import telepot
from telepot.loop import MessageLoop
from pprint import pprint
import wget
import pandas as pd
from pandas import read_excel
from openpyxl import load_workbook


def handle(msg):
    content_type, chat_type, chat_id = telepot.glance(msg)

    if content_type == 'text':
        bot.sendMessage(chat_id, 'Я жру файлы, Вась')
    elif content_type == 'document':
        print(msg['document']['file_id'])
        file_id = msg['document']['file_id']
        file_path = bot.getFile(file_id)['file_path']
        file_input_name = msg['document']['file_name']
        file_output_name = file_path[9:]
        print(file_path, file_id, file_input_name)
        url = 'https://api.telegram.org/file/bot' + TOKEN + '/' + file_path
        wget.download(url, '/content')
        file_to_output_location = '/content/' + file_output_name
        bot.sendDocument(chat_id, document=open(file_to_output_location, 'rb'))

TOKEN = '1034981722:AAG2226xw1d4qW23lPaVeeb7fzMfI8ZiHu0'
bot = telepot.Bot(TOKEN)
MessageLoop(bot, handle).run_as_thread()
print ('Listening ...')
while 1:
    time.sleep(10)
# Out:
#   File "<ipython-input-2-0981ff7608c1>", line 29
#     telepot.api.set_proxy(http://94.241.237.77:8080 basic_auth=None)
#                               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from pandas import read_excel
df=pd.read_excel('/content/' + 'file_9.xlsx')
df.head()
# Out:
#   # Name: \\filer-waw.corp.retn.net\Homefolders\nvasyliv\Documents\VLUforPy.tsv  ... Unnamed: 23
# 0                                   # Version:19.0.0                             ...         NaN
# 1                    # Software Version:R19.0.0.0170                             ...         NaN
# 2                        # Date: 2019-10-27 13:24:43                             ...         NaN
# 3                      # Tool: Cross-Connect Manager                             ...         NaN
# 4                          # TimeZone: Europe/Moscow                             ...         NaN
#
# [5 rows x 24 columns]

# %%
from telepot.loop import MessageLoop
def handle(msg):
    content_type, chat_type, chat_id = telepot.glance(msg)
    print( content_type, chat_type, chat_id )
TOKEN = '1034981722:AAG2226xw1d4qW23lPaVeeb7fzMfI8ZiHu0'
bot = telepot.Bot(TOKEN)
MessageLoop(bot, handle).run_as_thread()
print ('Listening ...')
# Out:
# Listening ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/telepot/loop.py", line 60, in run_forever
#     allowed_updates=allowed_updates)
#   File "/usr/local/lib/python3.6/dist-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/usr/local/lib/python3.6/dist-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/usr/local/lib/python3.6/dist-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# ...
